# %%
# !python full_eval.py -m360 "E:\stv\study\FinalExam\gaussian-splatting\assets\360_v2" ^
-tat  "E:\stv\study\FinalExam\gaussian-splatting\assets\tandt_db\tandt" ^
-db  "E:\stv\study\FinalExam\gaussian-splatting\assets\tandt_db\db" ^
  --output_path "E:\stv\study\FinalExam\gaussian-splatting\eval_baseline1"
# Out:
# ^C
